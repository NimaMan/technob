# %% [markdown]
# # Beat Tracking

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio
from scipy.io import wavfile

# %% [markdown]
# # Beat Tracking using madmom
#
# Currently having some installation issues on mac osx.

# %%
import madmom
from madmom.features.beats import RNNBeatProcessor, DBNBeatTrackingProcessor
from madmom.features.downbeats import RNNDownBeatProcessor, DBNDownBeatTrackingProcessor
from madmom.features.tempo import TempoEstimationProcessor

# %%
# Load the music file
audio_file = "cse.wav"
y, sr = librosa.load(audio_file)

# Now, let's use the "madmom" library to perform Beat Tracking
beats = madmom.features.beats.DBNBeatTrackingProcessor()(audio_file)

# Let's visualize the magical beats
plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.vlines(librosa.frames_to_time(beats), -1, 1, color='r', alpha=0.9, linestyle='--', label='Beats')
plt.title("Unraveling Magical Rhythms - Beat Tracking")
plt.xlabel("Time (seconds)")
plt.ylabel("Amplitude")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ...
#   Using cached madmom-0.16.1.tar.gz (20.0 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [162 lines of output]
#       /Users/nimamanaf/opt/anaconda3/envs/q/lib/python3.9/site-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
# ...
